# %% [markdown]
# # Benchmark, No Denoising vs. PCA Denoising vs. RPCA Denoising
# ### Discriminibility Setting:
#   * 4 Subjects
#   * 11, 11, 11, and 9 trials.
#   * Metric: Frobenius Norm
#   * Data derivitive on which metric is computed: Correlation Matrix
#   * Hard-Coded parameters: maximum of 10 iterations on RPCA

# %%
import pickle as pkl
from auto_bench.results import (bench_report,
                                compare_results,
                                crossval_plot)
from auto_bench.main import metric_test, best_param_combo

# %%
exp_dir = 'interpolate_10/'
with open('results/' + exp_dir + 'interpolate_10_param_map.pkl', 'r') as f:
    pmap_10 = pkl.load(f)
    del pmap_10['coords']
with open('results/' + exp_dir + 'interpolate_10.pkl', 'r') as f:
    R_10 = pkl.load(f).flatten()
with open('results/' + exp_dir + 'opti_crossval.pkl', 'r') as f:
    res_10 = pkl.load(f)
    del res_10[1]['coords']
    
exp_dir = 'default_10/'
with open('results/' + exp_dir + 'interpolate_10_param_map.pkl', 'r') as f:
    pmap_10d = pkl.load(f)
with open('results/' + exp_dir + 'interpolate_10.pkl', 'r') as f:
    R_10d = pkl.load(f).flatten()
with open('results/' + exp_dir + 'opti_crossval.pkl', 'r') as f:
    res_10d = pkl.load(f)
    
exp_dir = 'interpolate_15/'
with open('results/' + exp_dir + 'interpolate_10_param_map.pkl', 'r') as f:
    pmap_15 = pkl.load(f)
    del pmap_15['coords']
with open('results/' + exp_dir + 'interpolate_10.pkl', 'r') as f:
    R_15 = pkl.load(f).flatten()
with open('results/' + exp_dir + 'opti_crossval.pkl', 'r') as f:
    res_15 = pkl.load(f)
    del res_15[1]['coords']
    
exp_dir = 'default_15/'
with open('results/' + exp_dir + 'interpolate_10_param_map.pkl', 'r') as f:
    pmap_15d = pkl.load(f)
with open('results/' + exp_dir + 'interpolate_10.pkl', 'r') as f:
    R_15d = pkl.load(f).flatten()
with open('results/' + exp_dir + 'opti_crossval.pkl', 'r') as f:
    res_15d = pkl.load(f)
    
exp_dir = 'interpolate_20/'
with open('results/' + exp_dir + 'interpolate_10_param_map.pkl', 'r') as f:
    pmap_20 = pkl.load(f)
    del pmap_20['coords']
with open('results/' + exp_dir + 'interpolate_10.pkl', 'r') as f:
    R_20 = pkl.load(f).flatten()
with open('results/' + exp_dir + 'opti_crossval.pkl', 'r') as f:
    res_20 = pkl.load(f)
    del res_20[1]['coords']
    
exp_dir = 'default_20/'
with open('results/' + exp_dir + 'interpolate_10_param_map.pkl', 'r') as f:
    pmap_20d = pkl.load(f)
with open('results/' + exp_dir + 'interpolate_10.pkl', 'r') as f:
    R_20d = pkl.load(f).flatten()
with open('results/' + exp_dir + 'opti_crossval.pkl', 'r') as f:
    res_20d = pkl.load(f)
    
exp_dir = 'interpolate_25/'
with open('results/' + exp_dir + 'interpolate_10_param_map.pkl', 'r') as f:
    pmap_25 = pkl.load(f)
    del pmap_25['coords']
with open('results/' + exp_dir + 'interpolate_10.pkl', 'r') as f:
    R_25 = pkl.load(f).flatten()
with open('results/' + exp_dir + 'opti_crossval.pkl', 'r') as f:
    res_25 = pkl.load(f)
    del res_25[1]['coords']
    
exp_dir = 'default_25/'
with open('results/' + exp_dir + 'interpolate_10_param_map.pkl', 'r') as f:
    pmap_25d = pkl.load(f)
with open('results/' + exp_dir + 'interpolate_10.pkl', 'r') as f:
    R_25d = pkl.load(f).flatten()
with open('results/' + exp_dir + 'opti_crossval.pkl', 'r') as f:
    res_25d = pkl.load(f)
    
exp_dir = 'interpolate_30/'
with open('results/' + exp_dir + 'interpolate_10_param_map.pkl', 'r') as f:
    pmap_30 = pkl.load(f)
    del pmap_30['coords']
with open('results/' + exp_dir + 'interpolate_10.pkl', 'r') as f:
    R_30 = pkl.load(f).flatten()
with open('results/' + exp_dir + 'opti_crossval.pkl', 'r') as f:
    res_30 = pkl.load(f)
    del res_30[1]['coords']
    
exp_dir = 'default_30/'
with open('results/' + exp_dir + 'interpolate_10_param_map.pkl', 'r') as f:
    pmap_30d = pkl.load(f)
with open('results/' + exp_dir + 'interpolate_10.pkl', 'r') as f:
    R_30d = pkl.load(f).flatten()
with open('results/' + exp_dir + 'opti_crossval.pkl', 'r') as f:
    res_30d = pkl.load(f)
    
exp_dir = 'interpolate_35/'
with open('results/' + exp_dir + 'interpolate_10_param_map.pkl', 'r') as f:
    pmap_35 = pkl.load(f)
    del pmap_35['coords']
with open('results/' + exp_dir + 'interpolate_10.pkl', 'r') as f:
    R_35 = pkl.load(f).flatten()
with open('results/' + exp_dir + 'opti_crossval.pkl', 'r') as f:
    res_35 = pkl.load(f)
    del res_35[1]['coords']
    
exp_dir = 'default_35/'
with open('results/' + exp_dir + 'interpolate_10_param_map.pkl', 'r') as f:
    pmap_35d = pkl.load(f)
with open('results/' + exp_dir + 'interpolate_10.pkl', 'r') as f:
    R_35d = pkl.load(f).flatten()
with open('results/' + exp_dir + 'opti_crossval.pkl', 'r') as f:
    res_35d = pkl.load(f)

# %%
bench_report(R_10, pmap_10, '10 Chan Bad Interpolate', 'Frob. Correlation Metric')
bench_report(R_15, pmap_15, '15 Chan Bad Interpolate', 'Frob. Correlation Metric')
bench_report(R_20, pmap_20, '20 Chan Bad Interpolate', 'Frob. Correlation Metric')
bench_report(R_25, pmap_25, '25 Chan Bad Interpolate', 'Frob. Correlation Metric')
bench_report(R_30, pmap_30, '30 Chan Bad Interpolate', 'Frob. Correlation Metric')
bench_report(R_35, pmap_35, '35 Chan Bad Interpolate', 'Frob. Correlation Metric')

# %%
compare_results([(R_10, '10 bad.'),
                 (R_15, '15 bad.'),
                 (R_20, '20 bad.'),
                 (R_25, '25 bad.'),
                 (R_30, '30 bad.'),
                 (R_35, '35 bad.')
                ],
                'Interpolation Benchmarking')

# %%
print 'PCA best param setting:', res_10[1], ' with a discriminibility of', R_10[res_10[2][0]]
crossval_plot([res_10d[0], res_10[0]],
              names=['10 Chans Bad Default', '10 Chans Bad Interpolated'],
              title='Leave-One-Out Discriminibility Distribution, Interpolation')
# Out:
# PCA best param setting: {'s': 10000}  with a discriminibility of 0.627826167306
# /usr/local/lib/python2.7/dist-packages/seaborn/categorical.py:2342: UserWarning: The violinplot API has been changed. Attempting to adjust your arguments for the new API (which might not work). Please update your code. See the version 0.6 release notes for more info.
#   warnings.warn(msg, UserWarning)

# %%
print 'PCA best param setting:', res_15[1], ' with a discriminibility of', R_15[res_15[2][0]]
crossval_plot([res_15d[0], res_15[0]],
              names=['15 Chans Bad Default', '15 Chans Bad Interpolated'],
              title='Leave-One-Out Discriminibility Distribution, Interpolation')
# Out:
# PCA best param setting: {'s': 10000}  with a discriminibility of 0.626622508182

# %%
print 'PCA best param setting:', res_20[1], ' with a discriminibility of', R_20[res_10[2][0]]
crossval_plot([res_20d[0], res_20[0]],
              names=['20 Chans Bad Default', '20 Chans Bad Interpolated'],
              title='Leave-One-Out Discriminibility Distribution, Interpolation')
# Out:
# PCA best param setting: {'s': 10000}  with a discriminibility of 0.62394771013

# %%
print 'PCA best param setting:', res_25[1], ' with a discriminibility of', R_25[res_25[2][0]]
crossval_plot([res_25d[0], res_25[0]],
              names=['25 Chans Bad Default', '25 Chans Bad Interpolated'],
              title='Leave-One-Out Discriminibility Distribution, Interpolation')
# Out:
# PCA best param setting: {'s': 10000}  with a discriminibility of 0.627638931442

# %%
print 'PCA best param setting:', res_30[1], ' with a discriminibility of', R_30[res_30[2][0]]
crossval_plot([res_30d[0], res_30[0]],
              names=['30 Chans Bad Default', '30 Chans Bad Interpolated'],
              title='Leave-One-Out Discriminibility Distribution, Interpolation')
# Out:
# PCA best param setting: {'s': 10000}  with a discriminibility of 0.62319633504

# %%
print 'PCA best param setting:', res_35[1], ' with a discriminibility of', R_35[res_35[2][0]]
crossval_plot([res_35d[0], res_35[0]],
              names=['35 Chans Bad Default', '35 Chans Bad Interpolated'],
              title='Leave-One-Out Discriminibility Distribution, Interpolation')
# Out:
# PCA best param setting: {'s': 10000}  with a discriminibility of 0.62110512929

# %%
crossval_plot([res_10d[0], res_15d[0], res_20d[0], res_25d[0], res_30d[0], res_35d[0]],
              names=['10 Default','15 Default','20 Default','25 Default','30 Default','35 Default'],
              title='Leave-One-Out Discriminibility Distribution, Defaults')

# %%
crossval_plot([res_10[0], res_15[0], res_20[0], res_25[0], res_30[0], res_35[0]],
              names=['10 Interp','15 Interp','20 Interp','25 Interp','30 Interp','35 Interp'],
              title='Leave-One-Out Discriminibility Distribution, Interpolateds')
