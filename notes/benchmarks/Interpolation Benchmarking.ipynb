# %%
import cPickle as pkl
import numpy as np
import sys
sys.path.append('../..')
import bench.discriminibility as disc
import bench.disc_set as d_set
import os
os.chdir('../../../data')
import glob as glob

# %%
with open('results/raw_results.pkl', 'r') as f:
    raw = zip(*pkl.load(f))[0]
with open('results/ssi_interp.pkl', 'r') as f:
    ssi = zip(*pkl.load(f))[0]
with open('results/wave_inter.pkl', 'r') as f:
    winter5 = zip(*pkl.load(f))[0]
with open('results/wave_inter2.pkl', 'r') as f:
    winter2 = zip(*pkl.load(f))[0]
with open('results/zero_cmi_bad.pkl', 'r') as f:
    zbc = zip(*pkl.load(f))[0]
with open('results/CMI_results.pkl', 'r') as f:
    cmi = zip(*pkl.load(f))[0]

# %%
discs = [raw, zbc, ssi, winter2, winter5, cmi]
names = ['raw', 'zbc', 'ssi', 'winter2', 'winter5', 'cmi']
disc.disc_plot(discs, d_set.NAMES, names)
import matplotlib.pyplot as plt
plt.title('Interpolation Benchmarking')
plt.xlabel('Experiment Name')
plt.ylabel('Discriminibility')
plt.show()
# Out:
# [[ 0.75895317  0.7100551   0.71921488]
#  [ 0.74669421  0.70103306  0.70998623]
#  [ 0.74731405  0.69311295  0.70950413]
#  [ 0.75089532  0.69827824  0.71921488]
#  [ 0.75385675  0.70819559  0.72093664]
#  [ 0.87078235  0.62711093  0.61207458]]
