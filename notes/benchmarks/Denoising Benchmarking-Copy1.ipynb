# %%
import cPickle as pkl
import numpy as np
import sys
sys.path.append('../..')
import bench.discriminibility as disc
import bench.disc_set as d_set
import os
os.chdir('../../../data')
import glob as glob
with open('results/CMI_results.pkl', 'r') as f:
    cmi = zip(*pkl.load(f))[0]

# %%
raw = [.759, .71, .72]
hpf = [.925, .717, .7365]
bpf = [.9307, .723, .754]
eog = [.843, .7216, .6944]
rpca = [.843, .72, .695]

# %%
discs = [raw, hpf, bpf, eog, rpca, cmi]
names = ['raw', 'hpf', 'bpf', 'eog', 'rpca', 'cmi']
disc.disc_plot(discs, d_set.NAMES, names)
import matplotlib.pyplot as plt
plt.title('Denoising Benchmarking')
plt.xlabel('Experiment Name')
plt.ylabel('Discriminibility')
plt.show()
# Out:
# [[ 0.759       0.71        0.72      ]
#  [ 0.925       0.717       0.7365    ]
#  [ 0.9307      0.723       0.754     ]
#  [ 0.843       0.7216      0.6944    ]
#  [ 0.843       0.72        0.695     ]
#  [ 0.87078235  0.62711093  0.61207458]]
